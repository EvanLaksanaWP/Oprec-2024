# %% [markdown]
# <div style="text-align: center;">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/3/31/NumPy_logo_2020.svg" alt="Numpy Logo" width="500">
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/1280px-Pandas_logo.svg.png" alt="Pandas Logo" width="500">
#     <p style="font-size: 50px; font-weight: bold;">Pengenalan NumPy dan Pandas pada Python</p>
#     <p style="font-size: 50px; font-weight: normal;"> Intern BCC 2024</p>
# </div>

# %% [markdown]
# # Numpy 🧮

# %% [markdown]
# **NumPy** atau Numerical Python adalah sebuah library Python yang menyediakan struktur data dan fungsi-fungsi untuk bekerja dengan array dan matriks multidimensi. **NumPy** meningkatkan efisiensi dalam melakukan operasi dan manipulasi data dengan ukuran yang besar

# %% [markdown]
# # Pandas 🐼
#
# **Pandas** adalah sebuah library Python yang digunakan untuk manipulasi dan analisis data. **Pandas** menyediakan struktur data yang fleksibel dan kaya akan fitur untuk mengolah data tabular, seperti data yang ada pada file CSV atau spreadsheet. Library ini sangat berguna untuk mempersiapkan data untuk analisis dan pemodelan statistik. Pandas juga memiliki banyak fungsi untuk melakukan operasi matematika dan statistik.

# %% [markdown]
# ## Import Pandas

# %%
import pandas as pd
print(pd)
# Out:
# <module 'pandas' from 'c:\\Users\\user\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\pandas\\__init__.py'>

# %% [markdown]
# ## Read CSV
#
# Pandas dapat membaca file dengan format file csv ataupun excel lalu dikonversi ke tipe data DataFrame.

# %%
# Mengambil dari file path lokal
data = pd.read_csv("./titanic.csv")

# Mengambil dari GitHub
data = pd.read_csv(
    "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# Mengambil dari Google Drive ( drive.google.com/file/d/1cxttBfHGltz1enyM_BQYiedU73t5mKMX/view?usp=drive_link )
id = "1cxttBfHGltz1enyM_BQYiedU73t5mKMX"
data = pd.read_csv("https://drive.google.com/uc?id=" + id,
                   delimiter=',', index_col="PassengerId")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## DataFrame
#
# DataFrame pada Pandas adalah sebuah struktur data dua dimensi yang mirip dengan tabel terdiri dari baris dan kolom.
#
# Komponen pada DataFrame:
#
# 1. Data, Nilai-nilai yang disimpan di dalam DataFrame dengan tipe data yang dapat beragam
# 2. Index, Label unik pada setiap baris pada DataFrame
# 3. Columns Names, Label atau identifikasi terhadap data yang disimpan dalam suatu kolom
# 4. Data Types, Tipe data dari setiap kolom pada DataFrame

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Membuat DataFrame Secara Manual
#
# Untuk memahami lebih lanjut, DataFrame juga dapat dibuat dengan menggunakan bantuan struktur data **Dictionary** pada Python.
#
# - **Key** interpretasi dari label kolom dengan tipe data string
# - **Value** interpretasi dari data pada suatu kolom dengan tipe data list
# - Label index secara otomatis dibuat dari 0 hingga n

# %%
dict_data = {
    'Nama': ['Evan', 'Firhan', 'Byu', 'Mira'],
    'Jenis Kelamin': ['L', 'L', 'L', 'P'],
    'Tempat Tinggal': ['Banyuwangi', 'Bandung', 'Malang', 'Malang'],
    'Umur': [20, 21, 20, 21]
}

manual_df = pd.DataFrame(dict_data)
manual_df
# Out:
#      Nama Jenis Kelamin Tempat Tinggal  Umur
# 0    Evan             L     Banyuwangi    20
# 1  Firhan             L        Bandung    21
# 2     Byu             L         Malang    20
# 3    Mira             P         Malang    21

# %% [markdown]
# ### Modifikasi Komponen pada DataFrame

# %%
# Mengubah label kolom pada DataFrame
manual_df = manual_df.rename(columns={
                             'Nama': 'Name', 'Jenis Kelamin': 'Gender', 'Tempat Tinggal': 'Address', 'Umur': 'Age'})

# Mengubah label indeks pada DataFrame
manual_df.rename(index={2: 'index baru'}, inplace=True)

manual_df
# Out:
#               Name Gender     Address  Age
# 0             Evan      L  Banyuwangi   20
# 1           Firhan      L     Bandung   21
# index baru     Byu      L      Malang   20
# 3             Mira      P      Malang   21

# %% [markdown]
# ## Series
#
# Series dalam Pandas adalah struktur data satu dimensi yang mirip dengan array atau kolom dalam tabel. Series dapat menyimpan data dari berbagai tipe, seperti integer, float, string, atau objek Python. Satu hal yang membedakan Series dari array sederhana adalah adanya indeks yang menyertai setiap elemen dalam Series.
#
# Komponen pada Series:
#
# 1. Data, Nilai-nilai yang disimpan dalam Series yang dapat berupa berbagai jenis tipe data.
# 2. Index, Label unik pada setiap elemen pada Series, secara default akan diberikan index label dari 0 hingga n.

# %%
# Mengambil Series dari kolom Age pada Dataframe data
age_series = data["Age"]

print("Tipe data:", type(age_series))

age_series
# Out:
# Tipe data: <class 'pandas.core.series.Series'>
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# ### Membuat Series Secara Manual
#
# Untuk memahami lebih lanjut, Series juga dapat dibuat dengan menggunakan bantuan struktur data **List** pada Python.

# %%
list_data = ['Evan', 'Firhan', 'Bayu', 'Mira']
manual_series = pd.Series(list_data)
manual_series
# Out:
# 0      Evan
# 1    Firhan
# 2      Bayu
# 3      Mira
# dtype: object

# %% [markdown]
# ## Data Exploration Using Pandas

# %% [markdown]
# ### Head
#
# Mendapatkan baris n teratas pada data, default n = 5

# %%
data.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %% [markdown]
# ### Tail
#
# Mendapatkan baris n terbawah pada data, default n = 5

# %%
data.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Shape
#
# Mengembalikan sebuah _tuple_ yang berisi $(n, m)$
#
# $n$ = Jumlah baris pada data
#
# $m$ = Jumlah kolom pada data

# %%
data.shape
# Out:
# (891, 11)

# %% [markdown]
# ### Info
#
# Mendapatkan informasi detail dari setiap **kolom** pada data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# ### Describe
#
# Mendapatkan ringkasan statistik pada kolom-kolom **numerik**
#
# 1. count = Jumlah baris
# 2. mean = Rata-rata nilai
# 3. std = Standar Deviasi
# 4. min = Nilai paling kecil
# 5. 25% = Presentil bawah
# 6. 50% = Median
# 7. 75% = Presentil atas
# 8. max = Nilai paling besar

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Melihat Nilai Unik

# %%
data["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %% [markdown]
# ### Melihat Jumlah Nilai Unik

# %%
data["Pclass"].nunique()
# Out:
# 3

# %% [markdown]
# ### Melihat Jumlah Data untuk Setiap Nilai Unik

# %%
data["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### Seleksi
#
# Mendapatkan nilai pada baris atau kolom tertentu pada DataFrame

# %% [markdown]
# #### Seleksi menggunakan [ ]
#
# Indexing paling sederhana untuk mengambil data pada suatu kolom namun tidak bisa mengambil pada baris tertentu.
#
# **data[columns_name]**

# %%
# Mengambil semua data pada sebuah kolom tertentu dalam bentuk DataFrame
data[["Survived"]]
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0
# ...               ...
# 887                 0
# 888                 1
# 889                 0
# 890                 1
# 891                 0
#
# [891 rows x 1 columns]

# %%
# Mengambil semua data pada sebuah kolom tertentu dalam bentuk Series
data["Survived"]
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Mengambil semua data pada kolom tertentu
data[["Name", "Sex", "Age"]]
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# #### Seleksi Menggunakan loc
#
# Indexing menggunakan **label/nama** baris dan kolom
#
# **data.loc[row_label, column_label]**

# %%
# Mengambil baris index 0 hingga 5 pada semua kolom
data.loc[0:5, ]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Mengambil semua baris pada kolom tertentu
data.loc[:, ["Name", "Cabin"]]
# Out:
#                                                           Name Cabin
# PassengerId
# 1                                      Braund, Mr. Owen Harris   NaN
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   C85
# 3                                       Heikkinen, Miss. Laina   NaN
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# 5                                     Allen, Mr. William Henry   NaN
# ...                                                        ...   ...
# 887                                      Montvila, Rev. Juozas   NaN
# 888                               Graham, Miss. Margaret Edith   B42
# 889                   Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                                      Behr, Mr. Karl Howell  C148
# 891                                        Dooley, Mr. Patrick   NaN
#
# [891 rows x 2 columns]

# %%
# Mengambil range index baris ternetu pada kolom tertentu menggunakan list
data.loc[887:891, ["Name", "Age"]]
# Out:
#                                                  Name   Age
# PassengerId
# 887                             Montvila, Rev. Juozas  27.0
# 888                      Graham, Miss. Margaret Edith  19.0
# 889          Johnston, Miss. Catherine Helen "Carrie"   NaN
# 890                             Behr, Mr. Karl Howell  26.0
# 891                               Dooley, Mr. Patrick  32.0

# %%
# Mengambil range index baris ternetu pada range kolom tertentu
data.loc[0:5, "Name":"Age"]
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0

# %%
# Mengambil baris index tertentu dan pada kolom tertentu menggunakan list
data.loc[[1, 5, 881, 886], ['Name', 'Age']]
# Out:
#                                                      Name   Age
# PassengerId
# 1                                 Braund, Mr. Owen Harris  22.0
# 5                                Allen, Mr. William Henry  35.0
# 881          Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 886                  Rice, Mrs. William (Margaret Norton)  39.0

# %% [markdown]
# #### Seleksi Menggunakan iloc
#
# Indexing menggunakan **index integer**, cara penggunaan mirip dengan loc namun menggunakan index integer
#
# **data.iloc[row_index, column_index]**

# %%
# Mengambil range baris tertentu pada range kolom tertentu
data.iloc[1:5, 0:5]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0

# %%
# Mengambil semua baris pada kolom tertentu
data.iloc[:, [0, 5]]
# Out:
#              Survived  SibSp
# PassengerId
# 1                   0      1
# 2                   1      1
# 3                   1      0
# 4                   1      1
# 5                   0      0
# ...               ...    ...
# 887                 0      0
# 888                 1      0
# 889                 0      1
# 890                 1      0
# 891                 0      0
#
# [891 rows x 2 columns]

# %% [markdown]
# #### Seleksi Index Boolean
#
# .loc dan [ ] dapat digunakan sebagai **Boolean Indexing**

# %%
# Mengembalikan hasil operasi boolean dalam bentuk struktur data 1 dimensi
filter_umur_balita = data["Age"] < 5
filter_umur_balita
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
# Mengembalikan baris data yang bernilai True atau memenuhi kondisi kolom Age < 5 (Balita)
data[filter_umur_balita]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 8                   0       3            Palsson, Master. Gosta Leonard
# 11                  1       3           Sandstrom, Miss. Marguerite Rut
# 17                  0       3                      Rice, Master. Eugene
# 44                  1       2  Laroche, Miss. Simonne Marie Anne Andree
# 64                  0       3                     Skoog, Master. Harald
# 79                  1       2             Caldwell, Master. Alden Gates
# 120                 0       3         Andersson, Miss. Ellis Anna Maria
# 165                 0       3              Panula, Master. Eino Viljami
# 172                 0       3                      Rice, Master. Arthur
# 173                 1       3              Johnson, Miss. Eleanor Ileen
# 184                 1       2                 Becker, Master. Richard F
# 185                 1       3       Kink-Heilmann, Miss. Luise Gretchen
# ...

# %%
# Menampilkan baris data dengan Age < 5 dan Survived == 0

data[(data["Age"] < 5) & (data["Survived"] == 0)]
# Out:
#              Survived  Pclass                                     Name  \
# PassengerId
# 8                   0       3           Palsson, Master. Gosta Leonard
# 17                  0       3                     Rice, Master. Eugene
# 64                  0       3                    Skoog, Master. Harald
# 120                 0       3        Andersson, Miss. Ellis Anna Maria
# 165                 0       3             Panula, Master. Eino Viljami
# 172                 0       3                     Rice, Master. Arthur
# 206                 0       3               Strom, Miss. Telma Matilda
# 298                 0       1             Allison, Miss. Helen Loraine
# 375                 0       3               Palsson, Miss. Stina Viola
# 387                 0       3          Goodwin, Master. Sidney Leonard
# 643                 0       3            Skoog, Miss. Margit Elizabeth
# 825                 0       3             Panula, Master. Urho Abraham
# ...

# %%
# Menampilkan baris data dengan Age < 5 atau Survived == 0

data[(data["Age"] < 5) | (data["Survived"] == 0)]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 7                   0       1                   McCarthy, Mr. Timothy J
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch           Ticket     Fare Cabin  \
# PassengerId
# ...

# %% [markdown]
# ## Pandas untuk Data Cleaning

# %% [markdown]
# ### Nilai Kosong
#
# **isna()** Akan mengembalikan **True** jika sel bernilai **null/Nan**

# %%
data.isna()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# ...

# %%
# sum() akan menampilkan banyak null tiap kolom
null_per_column = data.isna().sum()
null_per_column
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ### Membersihkan Nilai Kosong

# %%
data.dropna(inplace=True)
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# ### Data Duplikat
#
# **duplicated()** mengembalikan **True** jika baris terduplikasi

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Membersihkan Data Duplikat

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Menghapus Baris & Kolom

# %%
copy_data = data.copy()
copy_data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S
# 7                0      0     17463  51.8625   E46        S
# ...

# %% [markdown]
# **labels**
#
# - _single label or list-like_: Index or column labels to drop. A tuple will be used as a single label and not treated as a list-like.
#
# **axis**
#
# - _{0 or 'index', 1 or 'columns'}_, default 0: Whether to drop labels from the index (0 or 'index') or columns (1 or 'columns').
#
# **index**
#
# - _single label or list-like_: Alternative to specifying axis (labels, axis=0 is equivalent to index=labels).
#
# **columns**
#
# - _single label or list-like_: Alternative to specifying axis (labels, axis=1 is equivalent to columns=labels).

# %%
copy_data.drop(index=[2, 4], axis=1, inplace=False)
# Out:
#              Survived  Pclass  \
# PassengerId
# 7                   0       1
# 11                  1       3
# 12                  1       1
# 22                  1       2
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                          Name     Sex   Age  \
# PassengerId
# 7                                     McCarthy, Mr. Timothy J    male  54.0
# 11                            Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                   Bonnell, Miss. Elizabeth  female  58.0
# 22                                      Beesley, Mr. Lawrence    male  34.0
# 24                               Sloper, Mr. William Thompson    male  28.0
# ...                                                       ...     ...   ...
# ...

# %% [markdown]
# ## Supplementary Material

# %% [markdown]
# ### GroupBy & Aggregation

# %% [markdown]
# ### Merge & Concat

# %% [markdown]
# ### Dataframe Visualization

# %% [markdown]
# ### Apply & ApplyMap

# %% [markdown]
# ### Pivot Table

# %% [markdown]
# ### Saving DataFrame

# %% [markdown]
# # QnA 🙏
